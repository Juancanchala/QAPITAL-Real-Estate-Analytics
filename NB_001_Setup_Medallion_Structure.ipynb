# %%
# Crear estructura Medallion Architecture en Lakehouse
# Proyecto: QAPITAL Real Estate Analytics

# Importar librerías
from notebookutils import mssparkutils

# Definir estructura de carpetas
folders = ['bronze', 'silver', 'gold']

# Crear carpetas
for folder in folders:
    folder_path = f"Files/{folder}"
    
    # Verificar si existe, si no, crear
    try:
        mssparkutils.fs.mkdirs(folder_path)
        print(f"✅ Carpeta creada: {folder_path}")
    except Exception as e:
        print(f"⚠️ {folder}: {str(e)}")

print("\n🎉 Estructura Medallion creada exitosamente")
# Out:
# StatementMeta(, 8d721010-ab54-4368-b0d4-20a8baaf495f, 3, Finished, Available, Finished)
# ✅ Carpeta creada: Files/bronze
# ✅ Carpeta creada: Files/silver
# ✅ Carpeta creada: Files/gold
#
# 🎉 Estructura Medallion creada exitosamente
